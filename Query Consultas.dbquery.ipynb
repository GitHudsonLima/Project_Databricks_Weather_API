-- %%
select * from bronze.weather_raw
order by 1, 2, 3;

select * from weather_openmeteo.silver.weather_clean;

select * from weather_openmeteo.gold.weather_kpis 
where city = 'Beloit' order by 1, temperature desc;

Select count(*) from bronze.weather_raw;


delete  from bronze.weather_raw


select *
from bronze.weather_daily
